# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
from sklearn.model_selection import train_test_split

# %%
(x_train, y_train), (x_test, y_test) = keras.datasets.mnist.load_data()

# %%
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# %%
y_train = keras.utils.to_categorical(y_train, 10)
y_test = keras.utils.to_categorical(y_test, 10)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=42) # data validation

# %%
model = keras.Sequential([
    keras.layers.Conv2D(64,7,activation='relu',padding="same",input_shape=[28,28,1]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax") 
])

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x_train, y_train, epochs=100, batch_size=64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 54ms/step - accuracy: 0.6844 - loss: 0.9130 - val_accuracy: 0.9794 - val_loss: 0.0765
# Epoch 2/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9689 - loss: 0.1274 - val_accuracy: 0.9803 - val_loss: 0.0744
# Epoch 3/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9773 - loss: 0.0923 - val_accuracy: 0.9889 - val_loss: 0.0492
# Epoch 4/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9849 - loss: 0.0654 - val_accuracy: 0.9902 - val_loss: 0.0380
# Epoch 5/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9876 - loss: 0.0500 - val_accuracy: 0.9877 - val_loss: 0.0535
# Epoch 6/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9882 - loss: 0.0477 - val_accuracy: 0.9874 - val_loss: 0.0557
# Epoch 7/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 39s 51ms/step - accuracy: 0.9901 - loss: 0.0426 - val_accuracy: 0.9886 - val_loss: 0.0490
# Epoch 8/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9908 - loss: 0.0378 - val_accuracy: 0.9912 - val_loss: 0.0444
# Epoch 9/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 39s 53ms/step - accuracy: 0.9929 - loss: 0.0297 - val_accuracy: 0.9919 - val_loss: 0.0429
# Epoch 10/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9926 - loss: 0.0280 - val_accuracy: 0.9922 - val_loss: 0.0403
# Epoch 11/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9931 - loss: 0.0291 - val_accuracy: 0.9914 - val_loss: 0.0429
# Epoch 12/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 36s 48ms/step - accuracy: 0.9928 - loss: 0.0284 - val_accuracy: 0.9902 - val_loss: 0.0647
# Epoch 13/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9937 - loss: 0.0282 - val_accuracy: 0.9918 - val_loss: 0.0499
# Epoch 14/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9938 - loss: 0.0275 - val_accuracy: 0.9924 - val_loss: 0.0536
# Epoch 15/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9947 - loss: 0.0211 - val_accuracy: 0.9902 - val_loss: 0.0554
# Epoch 16/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9947 - loss: 0.0190 - val_accuracy: 0.9911 - val_loss: 0.0502
# Epoch 17/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 40s 53ms/step - accuracy: 0.9940 - loss: 0.0272 - val_accuracy: 0.9893 - val_loss: 0.0573
# Epoch 18/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 55ms/step - accuracy: 0.9958 - loss: 0.0170 - val_accuracy: 0.9890 - val_loss: 0.0628
# Epoch 19/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 55ms/step - accuracy: 0.9948 - loss: 0.0220 - val_accuracy: 0.9927 - val_loss: 0.0621
# Epoch 20/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.9941 - loss: 0.0299 - val_accuracy: 0.9915 - val_loss: 0.0626
# Epoch 21/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.9953 - loss: 0.0207 - val_accuracy: 0.9912 - val_loss: 0.0631
# Epoch 22/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - accuracy: 0.9965 - loss: 0.0155 - val_accuracy: 0.9910 - val_loss: 0.0553
# Epoch 23/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 57ms/step - accuracy: 0.9954 - loss: 0.0175 - val_accuracy: 0.9920 - val_loss: 0.0559
# Epoch 24/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 44s 59ms/step - accuracy: 0.9958 - loss: 0.0189 - val_accuracy: 0.9927 - val_loss: 0.0613
# Epoch 25/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 44s 58ms/step - accuracy: 0.9975 - loss: 0.0096 - val_accuracy: 0.9888 - val_loss: 0.0808
# Epoch 26/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 43s 58ms/step - accuracy: 0.9936 - loss: 0.0301 - val_accuracy: 0.9920 - val_loss: 0.0671
# Epoch 27/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.9959 - loss: 0.0185 - val_accuracy: 0.9925 - val_loss: 0.0581
# Epoch 28/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.
100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 50ms/step - accuracy: 0.9965 - loss: 0.0220 - val_accuracy: 0.9923 - val_loss: 0.1194
# Epoch 97/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 50ms/step - accuracy: 0.9976 - loss: 0.0154 - val_accuracy: 0.9922 - val_loss: 0.1284
# Epoch 98/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - accuracy: 0.9983 - loss: 0.0076 - val_accuracy: 0.9919 - val_loss: 0.1294
# Epoch 99/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - accuracy: 0.9978 - loss: 0.0118 - val_accuracy: 0.9916 - val_loss: 0.1481
# Epoch 100/100
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 38s 50ms/step - accuracy: 0.9965 - loss: 0.0219 - val_accuracy: 0.9926 - val_loss: 0.1229

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc:}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9918 - loss: 0.1195
# Test Accuracy: 0.9923999905586243

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0,1)
plt.show()

# %% [raw]
# Let's look at this graph in more detail

# %%
pd.DataFrame(history.history).plot(figsize=(8,5)) #
plt.grid(True)
plt.gca().set_ylim(0,0.3)
plt.show()

# %%
pd.DataFrame(history.history).plot(figsize=(8,5))
plt.grid(True)
plt.gca().set_ylim(0.95,1)
plt.show()

# %% [raw]
# The value of val_loss drops until about 12 iterations, and then starts to grow. vall_accuracy also stops growing at 12 iterations of training, which indicates that the model starts to overlearn.

# %%
model = keras.Sequential([
    keras.layers.Conv2D(64,7,activation='relu',padding="same",input_shape=[28,28,1]),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.Conv2D(128,3,activation='relu',padding="same"),
    keras.layers.MaxPooling2D(2),
    keras.layers.Flatten(),
    keras.layers.Dense(128,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(64,activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10, activation="softmax") 
])

# %%
model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

# %%
history = model.fit(x_train, y_train, epochs=12, batch_size=64, validation_data=(x_val, y_val))
# Out:
# Epoch 1/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 44s 56ms/step - accuracy: 0.6744 - loss: 0.9350 - val_accuracy: 0.9803 - val_loss: 0.0789
# Epoch 2/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 55ms/step - accuracy: 0.9702 - loss: 0.1251 - val_accuracy: 0.9820 - val_loss: 0.0750
# Epoch 3/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 41s 54ms/step - accuracy: 0.9786 - loss: 0.0901 - val_accuracy: 0.9883 - val_loss: 0.0481
# Epoch 4/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 40s 54ms/step - accuracy: 0.9859 - loss: 0.0617 - val_accuracy: 0.9887 - val_loss: 0.0485
# Epoch 5/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 40s 54ms/step - accuracy: 0.9880 - loss: 0.0519 - val_accuracy: 0.9908 - val_loss: 0.0416
# Epoch 6/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 42s 56ms/step - accuracy: 0.9881 - loss: 0.0518 - val_accuracy: 0.9896 - val_loss: 0.0449
# Epoch 7/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 39s 52ms/step - accuracy: 0.9905 - loss: 0.0429 - val_accuracy: 0.9900 - val_loss: 0.0496
# Epoch 8/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9916 - loss: 0.0430 - val_accuracy: 0.9909 - val_loss: 0.0412
# Epoch 9/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9925 - loss: 0.0309 - val_accuracy: 0.9904 - val_loss: 0.0507
# Epoch 10/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 50ms/step - accuracy: 0.9929 - loss: 0.0291 - val_accuracy: 0.9927 - val_loss: 0.0371
# Epoch 11/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 37s 49ms/step - accuracy: 0.9927 - loss: 0.0299 - val_accuracy: 0.9922 - val_loss: 0.0457
# Epoch 12/12
# 750/750 ━━━━━━━━━━━━━━━━━━━━ 39s 52ms/step - accuracy: 0.9921 - loss: 0.0333 - val_accuracy: 0.9926 - val_loss: 0.0446

# %%
test_loss, test_acc = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_acc}")
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9909 - loss: 0.0361
# Test Accuracy: 0.9930999875068665

# %% [raw]
# The result is a more flexible neural network that has a high accuracy rate and low loss, which indicates high accuracy and confidence of the model.

# %% [raw]
# Result: we will train the model up to 12 iterations
